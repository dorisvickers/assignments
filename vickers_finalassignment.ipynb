# %%
import pip
pip.main(['install','nltk'])
pip.main(['install','python-levenshtein'])
pip.main(['install','-U', 'spacy'])
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
#   Using cached python-Levenshtein-0.12.2.tar.gz (50 kB)
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
#   ERROR: Command errored out with exit status 1:
# ...

# %%
file = 'C:\\Users\\vickersd80\\Desktop\\DH STUFF\\Python\\jih.txt'
f=open(file,'r',encoding='utf-8')
data = f.read()
print('',data)
# Out:
#  Anfangsgründe der Elektrizität, hauptsächlich in Beziehung auf den Elektrophor.
# Einleitung.
# ...

# %%
# !pip install -U gensim
# Out:
# ...
#   Using cached gensim-4.1.2-cp39-cp39-win_amd64.whl (24.0 MB)
# ...
#   Using cached Cython-0.29.23-cp39-cp39-win_amd64.whl (1.7 MB)
# ...
#   Attempting uninstall: Cython
#     Found existing installation: Cython 0.29.24
#     Uninstalling Cython-0.29.24:
#       Successfully uninstalled Cython-0.29.24
# ...

# %%
import os
import time
import codecs
import string
import re
from collections import Counter
from collections import defaultdict

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import urllib
import requests
from bs4 import BeautifulSoup
import networkx as nx
import gensim

import nltk

from IPython.core.display import Image
# %matplotlib inline

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('brown')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\vickersd80\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\vickersd80\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\vickersd80\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\vickersd80\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\vickersd80\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# True

# %%
stop_de = nltk.corpus.stopwords.words('german')

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
list_words = data.split()
list_words = [l.strip().lower() for l in list_words]
list_words = [l.strip(string.punctuation) for l in list_words]
list_words = [l for l in list_words if l not in stop_de]
list_words[0:20]
# Out:
# ['anfangsgründe',
#  'elektrizität',
#  'hauptsächlich',
#  'beziehung',
#  'elektrophor',
#  'einleitung',
#  'seitdem',
#  'eitle',
#  'wortgepränge',
#  'zusammen',
#  'geist',
#  'einzige',
#  'kenntnis',
#  'beibrachte',
#  'physik',
#  'verbannt',
#  'argumenten',
#  'vielmehr',
#  'sophismen',
#  'untersuchungen']

# %%
# Counter object from https://docs.python.org/3/library/collections.html
from collections import Counter

freqdist = Counter(list_words)

# %%
freqdist.most_common(30)
# Out:
# [('luft', 1843),
#  (';', 993),
#  ('wasser', 650),
#  ('zwei', 339),
#  ('mehr', 290),
#  ('körper', 283),
#  ('menge', 282),
#  ('pflanzen', 277),
#  ('zeit', 254),
#  ('art', 232),
#  ('materie', 210),
#  ('dephlogistizierte', 188),
#  ('grad', 185),
#  ('sonne', 179),
#  ('versuche', 178),
#  ('herr', 177),
#  ('elektrizität', 174),
#  ('schon', 173),
#  ('röhre', 170),
#  ('teil', 169),
#  ('wurde', 168),
#  ('allein', 166),
#  ('natur', 164),
#  ('maß', 163),
#  ('pflanze', 163),
#  ('elektrische', 158),
#  ('wäre', 155),
#  ('scheint', 154),
#  ('feuer', 154),
#  ('sei', 150)]

# %%
#display stopwords
sw = set(nltk.corpus.stopwords.words ('german'))
print(len(sw))
list(sw) [:50]
# Out:
# 232
# ['unser',
#  'jede',
#  'wieder',
#  'sollte',
#  'welchen',
#  'selbst',
#  'du',
#  'seinen',
#  'ihnen',
#  'und',
#  'als',
#  'einigem',
#  'alle',
#  'sind',
#  'wenn',
#  'damit',
#  'des',
#  'hatten',
#  'hin',
#  'viel',
#  'auch',
#  'daß',
#  'meinem',
#  'ander',
#  'deine',
#  'können',
#  'jenen',
#  'ihre',
#  'dieser',
#  'keiner',
#  'eure',
#  'sein',
#  'doch',
#  'zwar',
#  'weil',
#  'welcher',
#  'dein',
#  'wie',
#  'ein',
#  'keines',
#  'anderes',
#  'wir',
#  'jedem',
#  'nichts',
#  'allen',
#  'musste',
#  'desselben',
#  'jedes',
#  'euren',
#  'oder']

# %%
import string
punctuation = set (string.punctuation)
filtered_words = [w.lower () for w in list_words if w.lower () not in sw
and w.lower () not in punctuation]
fd = nltk.FreqDist (list_words)
fd.most_common(20)
# Out:
# [('luft', 1843),
#  ('wasser', 650),
#  ('zwei', 339),
#  ('mehr', 290),
#  ('körper', 283),
#  ('menge', 282),
#  ('pflanzen', 277),
#  ('zeit', 254),
#  ('art', 232),
#  ('materie', 210),
#  ('dephlogistizierte', 188),
#  ('grad', 185),
#  ('sonne', 179),
#  ('versuche', 178),
#  ('herr', 177),
#  ('elektrizität', 174),
#  ('schon', 173),
#  ('röhre', 170),
#  ('teil', 169),
#  ('wurde', 168)]

# %%
#looking for words longer than 25 characters
long_words = [w for w in list_words if len(w)> 25]
sorted(long_words)
# Out:
# ['dreihundertfünfundsiebenzig',
#  'dreihundertsiebenundzwanzig',
#  'tausendhundertsechszigteil',
#  'weintrauben-lindenbaumblätter']

# %%
#looking for "phlogiston"
phlogist_words = [w for w in list_words if 'phlogist' in w]
phlogist_words = set(phlogist_words)
sorted(phlogist_words)
# Out:
# ['dephlogisticated',
#  'dephlogistigirten',
#  'dephlogistiziert',
#  'dephlogistizierte',
#  'dephlogistizierten',
#  'dephlogistizierter',
#  'dephlogistizierung',
#  'dephlogistizirte',
#  'dephlogistizirter',
#  'dephlogistlzierten',
#  'phlogistische',
#  'phlogistischen',
#  'phlogistischer',
#  'phlogistizieren',
#  'phlogistiziert',
#  'phlogistizierte',
#  'phlogistizierten',
#  'phlogiston',
#  'phlogistonfreien',
#  'phlogistons']

# %%
#looking for "platin"
platina_words = [w for w in list_words if 'platin' in w]
platina_words = set(platina_words)
sorted(platina_words)
# Out:
# ['platina', 'platinadraht']

# %%
#looking for "grün"
gruen_words = [w for w in list_words if 'grün' in w]
gruen_words = set(gruen_words)
sorted(gruen_words)
# Out:
# ['abgründe',
#  'anfangsgründe',
#  'anfangsgründen',
#  'beweggründe',
#  'beweisgründe',
#  'ergründen',
#  'gegründet',
#  'gegründete',
#  'gegründeter',
#  'gegründetes',
#  'grün',
#  'gründe',
#  'gründen',
#  'gründet',
#  'gründete',
#  'gründlich',
#  'gründlichkeit',
#  'grüne',
#  'grünen',
#  'grüner',
#  'grünes',
#  'grünlich',
#  'grünliche',
#  'grüns',
#  'hochgrün',
#  'schöngrünen',
#  'vernunftgründe']

# %%
#looking for bigrams
bgrms = nltk.FreqDist(nltk.bigrams(list_words))
bgrms.most_common(20)
# Out:
# [(('dephlogistizierte', 'luft'), 179),
#  (('dephlogistizierten', 'luft'), 138),
#  (('gemeine', 'luft'), 95),
#  (('grüne', 'materie'), 78),
#  (('elektrische', 'flüssige'), 77),
#  (('elektrischen', 'flüssigen'), 69),
#  (('gemeinen', 'luft'), 56),
#  (('dephlogistizierter', 'luft'), 49),
#  (('maß', 'salpetersäureluft'), 49),
#  (('grünen', 'materie'), 47),
#  (('brennbare', 'luft'), 46),
#  (('zwei', 'lüfte'), 46),
#  (('fixe', 'luft'), 43),
#  (('z', 'b'), 42),
#  (('menge', 'luft'), 42),
#  (('mehr', 'weniger'), 38),
#  (('große', 'menge'), 37),
#  (('herr', 'priestley'), 34),
#  (('königlichen', 'gesellschaft'), 33),
#  (('elektrische', 'feuer'), 31)]

# %%
#looking for trigrams
tgrms = nltk.FreqDist(nltk.trigrams (list_words))
tgrms.most_common(20)
# Out:
# [(('königlichen', 'gesellschaft', 'london'), 14),
#  (('maß', 'gemeine', 'luft'), 14),
#  (('kubikzoll', 'luft', 'wovon'), 12),
#  (('menge', 'elektrischen', 'flüssigen'), 11),
#  (('mischung', 'zwei', 'lüfte'), 11),
#  (('menge', 'dephlogistizierten', 'luft'), 11),
#  (('u', 's', 'w'), 10),
#  (('menge', 'dephlogistizierter', 'luft'), 10),
#  (('menge', 'dephlogistizierte', 'luft'), 10),
#  (('priestleysche', 'grüne', 'materie'), 10),
#  (('voll', 'dephlogistizierter', 'luft'), 9),
#  (('sonne', 'dephlogistizierte', 'luft'), 9),
#  (('teil', 'elektrischen', 'flüssigen'), 8),
#  (('immer', 'mehr', 'mehr'), 8),
#  (('art', 'leeren', 'raumes'), 8),
#  (('kubikzoll', 'dephlogistizierte', 'luft'), 8),
#  (('reinen', 'dephlogistizierten', 'luft'), 8),
#  (('wasser', 'sonne', 'ausgesetzt'), 8),
#  (('maß', 'salpetersäureluft', 'hinzu'), 8),
#  (('luft', 'deren', 'güte'), 7)]

# %% [markdown]
# # Wordclouds

# %%
# !pip install wordcloud
# Out:
# ...
#   Using cached wordcloud-1.8.1.tar.gz (220 kB)
# ...
#   Created wheel for wordcloud: filename=wordcloud-1.8.1-cp39-cp39-win_amd64.whl size=161111 sha256=300c54ce837691f62f4765bd777260530e56e769f1366370bc22b4c5471675c1
#   Stored in directory: c:\users\vickersd80\appdata\local\pip\cache\wheels\f9\7a\dd\06ef8b5dfe5483f6204133c08eeb16c287cc2c05e290ae2fc0
# Successfully built wordcloud
# ...

# %%
from wordcloud import WordCloud

cleaned = ' '.join(list_words)
wordcloud = WordCloud().generate(cleaned)

# %%
fig, ax = plt.subplots(figsize=(16, 12))
ax.imshow(wordcloud, interpolation='nearest')
plt.tight_layout()

# %%
# lower max_font_size
wordcloud = WordCloud(background_color="white", max_font_size=40).generate(cleaned)
plt.figure(figsize=(12, 12))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# The pil way (if you don't have matplotlib)
image = wordcloud.to_image()
image.show()

# %%
word = 'luft'
pos = 0 
positions = []

while pos != -1:
    position = cleaned.find(word,pos+1)
    pos = position
    positions.append(position)
positions.pop()
print(f'The word is found {len(positions)} times in the following positions:')
print(positions)
# Out:
# The word is found 2412 times in the following positions:
# ...

# %%
word = 'elektrizität'
pos = 0 
positions = []

while pos != -1:
    position = cleaned.find(word,pos+1)
    pos = position
    positions.append(position)
positions.pop()
print(f'The word is found {len(positions)} times in the following positions:')
print(positions)
# Out:
# The word is found 189 times in the following positions:
# ...

# %%
# Pure Python
window = 18
for position in positions[0:20]:
    print(cleaned[position - window:position + window + len(word)].strip())
# Out:
# physik lehre luft elektrizität aufmerksamkeit ph
# h interessant sei elektrizität überdies zweigen
# gemüte diejenigen elektrizität entstehen ursache
# fsinnigen theorie elektrizität bereichert kaum b
# klinschen systeme elektrizität system gelehrten
# lmehr erscheinung elektrizität zueignen allein s
# fenbare anzeichen elektrizität ebenso gibt körpe
# sichtbare zeichen elektrizität sobald teil natür
# befinden negative elektrizität erlangt isolierte
# usströhmen lassen elektrizität überladener körpe
# starken negativen elektrizität beladen ; spitze
# ommene abhandlung elektrizität schreiben gedenke
# bens laufen wolkenelektrizität belustigen versuc
# t grössere stärke elektrizität erwecken besonder
# kommen ausgefüllt elektrizität metallischen axe
# höpfung negativen elektrizität befinden leiter m
# gegenstand lehre elektrizität umfange entwerfen
# n stumpf geworden elektrizität allein kraft lebe
# sitiven negativen elektrizität erklärt geschicht

# %%
# Using NLTK

tknzr = nltk.tokenize.WordPunctTokenizer()
tokens = tknzr.tokenize(cleaned)
tokens = [token for token in tokens if token not in stop_de]
nltk_text = nltk.Text(tokens)

nltk_text.concordance(word.lower(), width=120, lines=20)
# Out:
# Displaying 20 of 174 matches:
# anfangsgründe elektrizität hauptsächlich beziehung elektrophor einleitung seitde
# emacht beweis eben behauptet teilen physik lehre luft elektrizität aufmerksamkeit philosophischer beobachter letzteren j
# lüssigen wesens unterworfen unendlich interessant sei elektrizität überdies zweigen natürlichen kenntnisse darin wesentl
#  hydrostatischer versuche ruhigeren gemüte diejenigen elektrizität entstehen ursachen ersteren bald fassen mühe entdecke
# e genie benjamin franklin welt scharfsinnigen theorie elektrizität bereichert kaum bekannt wurde schon fast allgemein an
# erster abschnitt kurzer begriff franklinschen systeme elektrizität system gelehrten höchst feines elastisches wesen körp
# anscheine gibt anzeichen daseins vielmehr erscheinung elektrizität zueignen allein sobald gleichgewicht flüssigen versch
# rlichen zustand eigen gibt körper offenbare anzeichen elektrizität ebenso gibt körper gleich sichtbare zeichen elektrizi
# ...

# %%
nltk_text.similar('luft')
# Out:
# menge wasser vorhanden berührung zwei jedoch besten pflanzen dabei
# brennbare lüfte dephlogistiziert elektrophor natur mehr großen anteil
# allein leicht unendlich

# %%
nltk_text.similar('elektrizität')
# Out:
# feuer stande negativen stand gesetzte funken gleichgewichtes
# überflüssigen wurmes

# %%
nltk_text.similar('dephlogistiziert')
# Out:
# luft vorhanden berührung besser nötig angefüllt unsichtbar

# %%
nltk_text.similar('elektrophor')
# Out:
# luft gesprochen

# %%
nltk_text.collocation_list(num=20, window_size=20)
# Out:
# [('maß', 'salpetersäureluft'),
#  ('maß', 'maß'),
#  ('luft', 'luft'),
#  ('elektrische', 'flüssige'),
#  ('elektrischen', 'flüssigen'),
#  ('grüne', 'materie'),
#  ('dephlogistizierte', 'luft'),
#  ('wasser', 'wasser'),
#  ('körper', 'körper'),
#  ('dephlogistizierten', 'luft'),
#  ('grünen', 'materie'),
#  ('leiter', 'leiter'),
#  ('salpetersäureluft', 'maß'),
#  ('flasche', 'flasche'),
#  ('königlichen', 'gesellschaft'),
#  ('maß', 'maßes'),
#  ('metallplatte', 'harzkuchen'),
#  ('pistole', 'pistole'),
#  ('leidner', 'flasche'),
#  ('spitze', 'spitze')]

# %%
max_items = 30
freq_min_b = 10
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder2 = nltk.collocations.BigramCollocationFinder.from_words(nltk_text)
finder2.apply_word_filter(lambda w: w in string.punctuation)
finder2.apply_freq_filter(freq_min_b)
for a, b in finder2.nbest(bigram_measures.pmi, max_items):
    print(a, b)
# Out:
# roten quecksilberniederschlag
# s w
# leeren raumes
# u s
# philosophischen transactionen
# säuerlich gemachten
# tremelle nostoch
# abt fontana
# königlichen gesellschaft
# z b
# hahn c
# gold silber
# luftartige flüssigkeit
# aufs neue
# priestleysche grüne
# gesellschaft london
# spitzigen blitzableiter
# leidner flasche
# zurückstoßende kraft
# of the
# tropfen äther
# weit entfernt
# magnetische kraft
# einzig allein
# elektrischen flüssigen
# elektrische flüssige
# siebenundneunzig grad
# ursache warum
# halben zoll
# röhre luftgütemessers

# %%
for a, b in (finder2.above_score(bigram_measures.raw_freq, 20.0 / len(list(nltk.bigrams(tokens))))):
        print(a, b)
# Out:
# dephlogistizierte luft
# dephlogistizierten luft
# gemeine luft
# grüne materie
# elektrische flüssige
# elektrischen flüssigen
# gemeinen luft
# dephlogistizierter luft
# maß salpetersäureluft
# grünen materie
# brennbare luft
# zwei lüfte
# fixe luft
# menge luft
# z b
# mehr weniger
# große menge
# herr priestley
# königlichen gesellschaft
# elektrische feuer
# kubikzoll luft
# brennbaren luft
# leidner flasche
# gleicher zeit
# maße salpetersäureluft
# gemeiner luft
# luft wasser
# fixer luft
# herr senebier
# sonne ausgesetzt
# wasser sonne
# magnetische kraft
# wasser luft
# grad güte
# fixen luft
# röhre luftgütemessers
# aufs neue
# brennbarer luft
# stand elektrizität

# %%
max_items = 30
freq_min_t = 6
trigram_measures = nltk.collocations.TrigramAssocMeasures()
finder3 = nltk.collocations.TrigramCollocationFinder.from_words(nltk_text)
finder3.apply_word_filter(lambda w: w in string.punctuation)
finder3.apply_ngram_filter(lambda w1, w2, w3:  w1 in ['da', 'de', 'das'])
finder3.apply_freq_filter(freq_min_t)
for a, b, c in finder3.nbest(trigram_measures.pmi, max_items):
    print(a, b, c)
# Out:
# barbier de tinan
# u s w
# bande philosophischen transactionen
# salpeter roten quecksilberniederschlag
# beim ersten anblick
# art leeren raumes
# königlichen gesellschaft london
# gekörnte grüne materie
# priestleysche grüne materie
# priestleyschen grünen materie
# säuerlich gemachten wasser
# maß salpetersäureluft hinzu
# elektrischen flüssigen verloren
# elektrische flüssige metallplatte
# mischung zwei lüfte
# nahm maß salpetersäureluft
# teil elektrischen flüssigen
# menge elektrischen flüssigen
# ausarbeitung dephlogistizierten luft
# voll dephlogistizierter luft
# schwerer gemeine luft
# wasser sonne ausgesetzt
# hervorbringung dephlogistizierten luft
# reinen dephlogistizierten luft
# immer mehr mehr
# luft röhre luftgütemessers
# kubikzoll luft wovon
# luft deren güte
# maß gemeine luft
# beschaffenheit gemeinen luft

# %%
for a, b, c in finder3.above_score(trigram_measures.raw_freq, 20.0 / len(list(nltk.trigrams(tokens)))):
        print (a, b, c)

# %%
from nltk.util import ngrams
n = 4
xgrams = ngrams(tokens, n)
xgrams_counter = Counter(xgrams)
xgrams_counter.most_common(20)
# Out:
# [(('zwei', 'zoll', 'sieben', 'linien'), 5),
#  (('herr', 'barbier', 'de', 'tinan'), 4),
#  (('große', 'menge', 'dephlogistizierte', 'luft'), 4),
#  (('lxviii', 'bande', 'philosophischen', 'transactionen'), 3),
#  (('mitglied', 'königlichen', 'gesellschaft', 'london'), 3),
#  (('zwei', 'negativ', 'elektrisierten', 'körpern'), 3),
#  (('nichtleitenden', 'körpern', 'eingeprägten', 'eigenschaft'), 3),
#  (('belegung', 'allgemeine', 'behältnis', 'überzugehen'), 3),
#  (('erster', 'abschnitt', 'vorläufige', 'betrachtungen'), 3),
#  (('dephlogistizierte', 'luft', 'daraus', 'erhalten'), 3),
#  (('nächtlichen', 'einfluss', 'pflanzen', 'ausgesetzte'), 3),
#  (('maß', 'salpetersäureluft', 'aufsteigen', 'lassen'), 3),
#  (('luft', 'deren', 'güte', 'kennen'), 3),
#  (('zeit', 'zwei', 'lüfte', 'einander'), 3),
#  (('dephlogistizierte', 'luft', 'salpeter', 'ziehen'), 3),
#  (('grad', ';', '500', '—'), 3),
#  ((';', 'heißt', 'maß', 'luft'), 3),
#  (('grad', ';', 'heißt', 'maß'), 3),
# ...

# %%
dispersion_words = ['luft', 'elektrizität', 'salpetersäureluft','elektrophor', 'materie', 'körper', 'wasser', 'pflanzen']
plt.figure(figsize=(16,6))
nltk_text.dispersion_plot(dispersion_words)

# %% [markdown]
# # Frequency analysis and graphs

# %%
freqdist.most_common(100)
# Out:
# [('luft', 1843),
#  (';', 993),
#  ('wasser', 650),
#  ('zwei', 339),
#  ('mehr', 290),
#  ('körper', 283),
#  ('menge', 282),
#  ('pflanzen', 277),
#  ('zeit', 254),
#  ('art', 232),
#  ('materie', 210),
#  ('dephlogistizierte', 188),
#  ('grad', 185),
#  ('sonne', 179),
#  ('versuche', 178),
#  ('herr', 177),
#  ('elektrizität', 174),
#  ('schon', 173),
#  ('röhre', 170),
#  ('teil', 169),
#  ('wurde', 168),
#  ('allein', 166),
#  ('natur', 164),
#  ('maß', 163),
#  ('pflanze', 163),
#  ('elektrische', 158),
#  ('wäre', 155),
#  ('scheint', 154),
#  ('feuer', 154),
#  ('sei', 150),
#  ('elektrischen', 144),
#  ('dephlogistizierten', 144),
#  ('stand', 141),
#  (':', 137),
#  ('davon', 136),
#  ('kraft', 136),
#  ('großen', 134),
#  ('darin', 134),
#  ('immer', 133),
#  ('substanz', 133),
#  ('flasche', 132),
#  ('salpetersäureluft', 132),
#  ('herrn', 131),
#  ('glas', 126),
#  ('ende', 126),
#  ('kubikzoll', 126),
#  ('gemeine', 125),
#  ('ursache', 124),
#  ('mittelst', 124),
# ...

# %%
labels, values = zip(*freqdist.most_common(30))

indexes = np.arange(len(labels))
width = 0.5

plt.bar(indexes, values, width)
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.xticks(indexes + width * 0.5, labels)
plt.show()

# %%
fd_words = nltk.FreqDist(tokens)
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(12,8)) 
fd_words.plot(30)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(12,8)) 
fd_words.plot(100, cumulative = True)
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Cumulative Counts'>

# %% [markdown]
# # Topic Modeling using gensim

# %%
# !pip install -U -q gensim mpld3 python-Levenshtein pyldavis
#!conda install -c conda-forge pyldavis
#!conda update -n base -c defaults conda

# %%
import re
import os
import codecs
import string
import numpy as np
import pandas as pd
import gensim
from gensim.test.utils import common_corpus, common_dictionary, get_tmpfile

import nltk
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.tokenize import word_tokenize

from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import matplotlib as mpl
from sklearn import feature_extraction
#import mpld3

#import pyLDAvis
#import pyLDAvis.gensim_models

from IPython.display import display, Image
from IPython.core.interactiveshell import InteractiveShell

# %matplotlib inline
#%matplotlib notebook

# %%
# !pip install gensim
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string

import gensim
from gensim import corpora

# %%
# !pip install gensim
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string

import gensim
from gensim import corpora

# %%
data = open('C:\\Users\\vickersd80\\Desktop\\DH STUFF\\Python\\jih.txt', encoding="utf8").read()
doc_dubious = []
doc_neutral = []
for i, line in enumerate(data.split("\n")):
    content = line.split()
    text = " ".join(content[1:])
    if label == "neutral":
        doc_neutral.append(text)
    else:
        doc_dubious.append(text)

doc_complete = doc_dubious

# %%
stop = set(stopwords.words('german'))
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()
def clean(doc):
    stop_free = " ".join([i for i in doc.lower().split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

doc_clean = [clean(doc).split() for doc in doc_complete]

# %%
# Creating the term dictionary of our courpus, where every unique term is assigned an index. 
dictionary = corpora.Dictionary(doc_clean)

# Converting list of documents (corpus) into Document Term Matrix using dictionary prepared above.
doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]
# Out:
# adding document #0 to Dictionary(0 unique tokens: [])
# built Dictionary(11656 unique tokens: ['beziehung', 'elektrizität', 'elektrophor', 'hauptsächlich', 'allgemein']...) from 995 documents (total 73528 corpus positions)
# Dictionary lifecycle event {'msg': "built Dictionary(11656 unique tokens: ['beziehung', 'elektrizität', 'elektrophor', 'hauptsächlich', 'allgemein']...) from 995 documents (total 73528 corpus positions)", 'datetime': '2022-02-04T09:25:33.605075', 'gensim': '4.1.2', 'python': '3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19042-SP0', 'event': 'created'}

# %%
# Creating the object for LDA model using gensim library
Lda = gensim.models.ldamodel.LdaModel

# Running and Trainign LDA model on the document term matrix.
ldamodel = Lda(doc_term_matrix, num_topics=10, id2word = dictionary, passes=50)
# Out:
# using symmetric alpha at 0.1
# using symmetric eta at 0.1
# using serial LDA version on this node
# running online (multi-pass) LDA training, 10 topics, 50 passes over the supplied corpus of 995 documents, updating model once every 995 documents, evaluating perplexity every 995 documents, iterating 50x with a convergence threshold of 0.001000
# -11.778 per-word bound, 3511.1 perplexity estimate based on a held-out corpus of 995 documents with 73528 words
# PROGRESS: pass 0, at document #995/995
# topic #8 (0.100): 0.019*"luft" + 0.012*"ist" + 0.011*"wasser" + 0.005*"habe" + 0.005*"hat" + 0.005*"pflanzen" + 0.005*"zeit" + 0.004*"sind" + 0.004*"mehr" + 0.004*"war"
# topic #6 (0.100): 0.020*"luft" + 0.006*"wasser" + 0.005*"war" + 0.004*"ist" + 0.004*"habe" + 0.003*"haben" + 0.003*"herr" + 0.003*"zeit" + 0.003*"hat" + 0.003*"körper"
# ...

# %%
#print(ldamodel.print_topics(num_topics=5, num_words=5))
for x in ldamodel.print_topics(num_topics=10, num_words=10):
    print(x)
# Out:
# topic #0 (0.100): 0.010*"materie" + 0.006*"haben" + 0.006*"natur" + 0.005*"grünen" + 0.005*"sei" + 0.004*"pole" + 0.004*"vermögen" + 0.004*"magnet" + 0.003*"nostoch" + 0.003*"kraft"
# topic #1 (0.100): 0.021*"luft" + 0.013*"grad" + 0.009*"fand" + 0.008*"hatte" + 0.006*"november" + 0.006*"versuche" + 0.006*"wetter" + 0.005*"war" + 0.005*"dezember" + 0.004*"beschaffenheit"
# topic #2 (0.100): 0.045*"luft" + 0.021*"wasser" + 0.011*"ist" + 0.009*"pflanzen" + 0.006*"sonne" + 0.006*"menge" + 0.006*"pflanze" + 0.006*"dephlogistizierte" + 0.006*"materie" + 0.005*"war"
# topic #3 (0.100): 0.016*"the" + 0.010*"of" + 0.007*"luft" + 0.006*"and" + 0.006*"salpeter" + 0.005*"schwefel" + 0.004*"that" + 0.004*"ist" + 0.003*"a" + 0.003*"is"
# topic #4 (0.100): 0.009*"metalle" + 0.009*"luft" + 0.008*"ist" + 0.006*"flamme" + 0.006*"platina" + 0.005*"gold" + 0.005*"metall" + 0.004*"eisen" + 0.004*"hitze" + 0.004*"hat"
# ...

# %%
#print(ldamodel.print_topics(num_topics=5, num_words=5))
for x in ldamodel.print_topics(num_topics=5, num_words=5):
    print(x)
# Out:
# topic #4 (0.100): 0.008*"luft" + 0.006*"pistole" + 0.006*"war" + 0.004*"kraft" + 0.004*"retorte"
# topic #0 (0.100): 0.012*"luft" + 0.012*"pflanzen" + 0.010*"ist" + 0.010*"habe" + 0.009*"haben"
# topic #3 (0.100): 0.007*"nadel" + 0.004*"magnetnadel" + 0.004*"versuch" + 0.004*"oberen" + 0.004*"wasser"
# topic #5 (0.100): 0.026*"luft" + 0.015*"maß" + 0.012*"salpetersäureluft" + 0.010*"wasser" + 0.009*"zwei"
# topic #9 (0.100): 0.049*"luft" + 0.019*"grad" + 0.011*"kubikzoll" + 0.010*"güte" + 0.009*"fand"
# (4, '0.008*"luft" + 0.006*"pistole" + 0.006*"war" + 0.004*"kraft" + 0.004*"retorte"')
# (0, '0.012*"luft" + 0.012*"pflanzen" + 0.010*"ist" + 0.010*"habe" + 0.009*"haben"')
# (3, '0.007*"nadel" + 0.004*"magnetnadel" + 0.004*"versuch" + 0.004*"oberen" + 0.004*"wasser"')
# (5, '0.026*"luft" + 0.015*"maß" + 0.012*"salpetersäureluft" + 0.010*"wasser" + 0.009*"zwei"')
# (9, '0.049*"luft" + 0.019*"grad" + 0.011*"kubikzoll" + 0.010*"güte" + 0.009*"fand"')

# %% [markdown]
# # Trying something else...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from os import path
import PIL
from PIL import Image
import nltk
import string
import re
import random
from collections import Counter
from wordcloud import WordCloud
from nltk.tokenize import word_tokenize 
#nltk.download('stopwords')
#nltk.download('punkt')
#nltk.download('wordnet')

# %%
file = 'C:\\Users\\vickersd80\\Desktop\\DH STUFF\\Python\\jih.txt'
f=open(file,'r',encoding='utf-8')
data = f.read()
print('',data)
# Out:
#  Anfangsgründe der Elektrizität, hauptsächlich in Beziehung auf den Elektrophor.
# Einleitung.
# ...

# %%
cleaned_data = data.lower()
cleaned_data = re.sub("\\* ", "", cleaned_data) 
cleaned_data = re.sub("\\-", "", cleaned_data) 
cleaned_data = re.sub('\\+',' ', cleaned_data) 
cleaned_data = re.sub('\\.','', cleaned_data) 
cleaned_data = re.sub('\\,','', cleaned_data)
cleaned_data = re.sub('\\;','', cleaned_data)
cleaned_data = re.sub('\\:','', cleaned_data)
print(len(cleaned_data))
print(cleaned_data)
# Out:
# 907896
# anfangsgründe der elektrizität hauptsächlich in beziehung auf den elektrophor
# einleitung
# seitdem das eitle wortgepränge welches alles zusammen dem geist nicht eine einzige kenntnis beibrachte aus der physik verbannt ist und man den argumenten oder vielmehr den sophismen untersuchungen der werke der natur entgegengehalten hat sind die wissenschaften auf einen grad gestiegen welchen man nicht vermutete dass sie ihn erreichen könnten und nachdem endlich die wut systeme zu schmieden der allgemein empfundenen notwendigkeit heutiges tages alles unser wissen auf sicherem grunde durch erfahrungen zu befestigen gewichen ist ist man nun überzeugt dass der gebrauch unseres geistes wofern er nicht durch das licht geleitet wird welches tatsachen und echte beobachtungen anstecken oft zu nichts diene als uns in irrtum zu stürzen der reißende fortgang den die neueren naturkundigen fast in allen teilen der physik gemacht haben ist der beweis von dem was ich so eben behauptet habe
# ...

# %%
stop_de = nltk.corpus.stopwords.words('german')

# %%
word_tokens = word_tokenize(cleaned_data) 
    
filtered_list = [] 
for w in word_tokens: 
    if w not in stop_de: 
        filtered_list.append(w) 
filtered_list
# Out:
# ['anfangsgründe',
#  'elektrizität',
#  'hauptsächlich',
#  'beziehung',
#  'elektrophor',
#  'einleitung',
#  'seitdem',
#  'eitle',
#  'wortgepränge',
#  'zusammen',
#  'geist',
#  'einzige',
#  'kenntnis',
#  'beibrachte',
#  'physik',
#  'verbannt',
#  'argumenten',
#  'vielmehr',
#  'sophismen',
#  'untersuchungen',
#  'werke',
#  'natur',
#  'entgegengehalten',
#  'wissenschaften',
#  'grad',
#  'gestiegen',
#  'vermutete',
#  'erreichen',
#  'könnten',
#  'nachdem',
#  'endlich',
#  'wut',
#  'systeme',
#  'schmieden',
#  'allgemein',
#  'empfundenen',
#  'notwendigkeit',
#  'heutiges',
#  'tages',
#  'wissen',
#  'sicherem',
#  'grunde',
#  'erfahrungen',
#  'befestigen',
#  'gewichen',
#  'überzeugt',
#  'gebrauch',
#  'geistes',
#  'wofern',
#  'licht',
#  'geleitet',
#  'tatsachen',
#  'echte',
#  'beobachtungen',
#  'anstecken',
#  'oft',
#  'diene',
#  'irrtum',
#  'stürzen',
#  'reißende',
#  'fortgang',
#  'neueren',
#  'naturkundigen',
#  'fast',
#  'teilen',
# ...

# %%
word_list = cleaned_data.split()
word_list = [l.strip().lower() for l in filtered_list]

word_list[0:20]
# Out:
# ['anfangsgründe',
#  'elektrizität',
#  'hauptsächlich',
#  'beziehung',
#  'elektrophor',
#  'einleitung',
#  'seitdem',
#  'eitle',
#  'wortgepränge',
#  'zusammen',
#  'geist',
#  'einzige',
#  'kenntnis',
#  'beibrachte',
#  'physik',
#  'verbannt',
#  'argumenten',
#  'vielmehr',
#  'sophismen',
#  'untersuchungen']

# %%
freqdist = Counter(word_list)
freqdist.most_common(50)
# Out:
# [('luft', 1843),
#  ('wasser', 650),
#  ('zwei', 339),
#  ('mehr', 290),
#  ('körper', 283),
#  ('menge', 282),
#  ('pflanzen', 277),
#  ('zeit', 254),
#  ('art', 232),
#  ('materie', 210),
#  ('dephlogistizierte', 188),
#  ('grad', 185),
#  ('sonne', 179),
#  ('versuche', 178),
#  ('herr', 177),
#  ('elektrizität', 174),
#  ('schon', 173),
#  ('röhre', 170),
#  ('teil', 169),
#  ('wurde', 168),
#  ('allein', 166),
#  ('natur', 164),
#  ('maß', 163),
#  ('pflanze', 163),
#  ('elektrische', 158),
#  ('wäre', 155),
#  ('scheint', 154),
#  ('feuer', 154),
#  ('sei', 150),
#  ('elektrischen', 144),
#  ('dephlogistizierten', 144),
#  ('stand', 141),
#  ('davon', 136),
#  ('kraft', 136),
#  ('großen', 134),
#  ('darin', 134),
#  ('immer', 133),
#  ('substanz', 133),
#  ('flasche', 132),
#  ('salpetersäureluft', 132),
#  ('herrn', 131),
#  ('glas', 126),
#  ('ende', 126),
#  ('kubikzoll', 126),
#  ('gemeine', 125),
#  ('ursache', 124),
#  ('mittelst', 124),
#  ('hätte', 122),
# ...

# %%
count_luft = freqdist["luft"]
count_elektrizität = freqdist["wasser"]
count_körper = freqdist["körper"]
#print(count_luft)
#print(count_elektrizität)
#print(count_körper)

bar_all = [count_luft, count_elektrizität, count_körper]
print(bar_all)
# Out:
# [1843, 650, 283]

# %%
#occurances of "elektrizität"
expression = 'elektrizität'

pos = 0 
positions = []

while pos != -1:
    position = cleaned_data.find(expression,pos+1)
    pos = position
    positions.append(position)
positions.pop()

print('The word "Elektrizität" is found {} times'.format(len(positions)))
#print(positions)
# Out:
# The word "Elektrizität" is found 189 times

# %%
# displaying context of elektrizität
tknzr = nltk.tokenize.WordPunctTokenizer()
tokens = tknzr.tokenize(cleaned_data)
tokens = [token for token in tokens if token not in stop_de]
nltk_text = nltk.Text(tokens)

nltk_text.concordance(expression.lower(), width=60, lines=10)
# Out:
# Displaying 10 of 174 matches:
# anfangsgründe elektrizität hauptsächlich beziehung
# eilen physik lehre luft elektrizität aufmerksamkeit philosop
# endlich interessant sei elektrizität überdies zweigen natürl
# geren gemüte diejenigen elektrizität entstehen ursachen erst
#  scharfsinnigen theorie elektrizität bereichert kaum bekannt
# f franklinschen systeme elektrizität system gelehrten höchst
# ns vielmehr erscheinung elektrizität zueignen allein sobald
# per offenbare anzeichen elektrizität ebenso gibt körper glei
# leich sichtbare zeichen elektrizität sobald teil natürlichen
# tande befinden negative elektrizität erlangt isoliertes seid

# %%
# contextualizing elektrizität
nltk_text.similar(expression)
# Out:
# feuer stande negativen stand gesetzte funken gleichgewichtes
# überflüssigen wurmes

# %%
#occurances of "luft"
expression = 'luft'

pos = 0 
positions = []

while pos != -1:
    position = cleaned_data.find(expression,pos+1)
    pos = position
    positions.append(position)
positions.pop()

print('The word "Luft" is found {} times'.format(len(positions)))
#print(positions)
# Out:
# The word "Luft" is found 2412 times

# %%
# displaying context of luft
tknzr = nltk.tokenize.WordPunctTokenizer()
tokens = tknzr.tokenize(cleaned_data)
tokens = [token for token in tokens if token not in stop_de]
nltk_text = nltk.Text(tokens)

nltk_text.concordance(expression.lower(), width=60, lines=10)
# Out:
# Displaying 10 of 1843 matches:
# hauptet teilen physik lehre luft elektrizität aufmerksamkeit
# hrten mehr verdient bedenke luft allgemeine element stütze l
# haftig wer erstaunen körper luft erheben wider gesetze allge
# ssige spitze davongeht maße luft verliert leiter getrieben s
# ektrische flüssige entweder luft benachbarten körpern maschi
# chzug feuchte erde eröffnen luft errichtete stange zimmer pr
# worauf harzkuchen befestigt luft ausstößt vermehrung elektri
# ft flüssigkeiten beim feuer luft statt flüssigkeiten vermöge
# gsam gemeinen holz feuchten luft mehreren körpern widerfährt
# itender körper z b trockene luft glas u d gl befindet schein

# %%
# contextualizing luft
nltk_text.similar(expression)
# Out:
# menge wasser vorhanden berührung zwei jedoch besten pflanzen dabei
# brennbare lüfte dephlogistiziert elektrophor natur mehr großen anteil
# allein leicht unendlich

# %% [markdown]
# # plots

# %%
labels, values = zip(*freqdist.most_common(10))

indexes = np.arange(len(labels))
width = 0.5

plt.bar(indexes, values, width)
fig = plt.gcf()
fig.set_size_inches(10.5, 4)
plt.xticks(indexes + width * 0.05, labels)
plt.title("The 10 most frequent words used by Jan Ingen-Housz", fontsize=18, color="royalblue")
plt.ylabel("No. of Occurences", fontweight="bold")
plt.show()

# %%
cleaned = ' '.join(cleaned_data)
wordcloud = WordCloud(font_path = 'arial', max_words = 50, background_color="lightgrey", colormap="tab10").generate(cleaned_data)
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.margins(x=0, y=0)
plt.show()
